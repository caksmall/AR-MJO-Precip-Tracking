# %%
from matplotlib.gridspec import GridSpec
from netCDF4 import Dataset
import matplotlib
import matplotlib.cm as cm 
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker
import matplotlib.colors
import matplotlib.colors as colors
from matplotlib.lines import Line2D
from matplotlib.patches import Patch
from matplotlib.colors import LogNorm
import numpy as np
from datetime import datetime, timedelta
import datetime as dt
import xarray as xr
import matplotlib.dates as mdates
import matplotlib.ticker as ticker
import matplotlib.colors as mcols
import glob 
import colorcet as cc
import netCDF4
import cmaps
from scipy.interpolate import interp2d
import cartopy
import cartopy.crs as ccrs
from cartopy.feature import NaturalEarthFeature
import matplotlib.gridspec as gridspec
import seaborn as sns
from cartopy.mpl.gridliner import LONGITUDE_FORMATTER, LATITUDE_FORMATTER
from pyproj import Proj
# from wrf import getvar, interplevel, to_np, latlon_coords, get_cartopy, cartopy_xlim, cartopy_ylim
from colorspacious import cspace_converter
import pathlib
from pathlib import Path
import numpy.ma as ma
from numpy import genfromtxt
import pandas as pd
import calendar
from IPython.core.pylabtools import figsize
from scipy import stats
from collections import Counter
from scipy.stats import mannwhitneyu
# Out:
# /home/disk/orca/csmall3/anaconda3/envs/new_2025_env/lib/python3.8/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# # Objective
# Make the rmm bar graphs. The data comes from the .py scripts in the `RMM_Dist` folder

# %% [markdown]
# ## Notes

# %% [markdown]
# MJO-Connected:
# - RMM 1 = 610
# - RMM 2 = 599
# - RMM 3 = 1,955
# - RMM 4 = 2,471
# - RMM 5 = 3,213
# - RMM 6 = 2,801
# - RMM 7 = 2,911 hours
# - RMM 8 = 1,014
#
# MJO-Active:
# - RMM 1 = 3,089
# - RMM 2 = 3,937
# - RMM 3 = 5,540
# - RMM 4 = 4,786
# - RMM 5 = 5,382
# - RMM 6 = 5,771
# - RMM 7 = 6,884
# - RMM 8 = 3,903

# %% [markdown]
# # RMM Bar Plots

# %%
mjo_conn_ts = [610,599,1955,2471,3213,2801,2911,1014]
mjo_act_ts = [3089,3837,5540,4786,5382,5771,6884,3903]

rmm_ph = [1,2,3,4,5,6,7,8]

# %%
# Create a bar plot
plt.bar(rmm_ph, mjo_act_ts)

# Add labels and title
plt.xlabel('Categories')
plt.ylabel('Values')
plt.title('Quick Bar Plot')

# Show the plot
plt.show()

# %%
ticksize =20
legendsize=19
legbox = 19
titlesize = 26


fig, ax = plt.subplots(figsize=[14, 7])

# Create a bar plot with custom color, opacity, and border
css=ax.bar(rmm_ph, mjo_act_ts, color='seagreen', alpha=0.7, edgecolor='black')

ax.set_title('DJFM MJO-Active RMM Hours', fontsize=titlesize)
ax.set_xlabel('[RMM Phase]', fontsize=legendsize)
ax.set_ylabel('[Hours]', fontsize=legendsize)
plt.yticks(fontsize=ticksize)
plt.xticks(fontsize=ticksize)

fig.savefig("/home/disk/orca/csmall3/AR_testing_research/JGR_Man_Scripts/Spatial_Distributions/MJO_LPT/Figures/MJO_Act_RMM_Hours_Dist.png", dpi=350, bbox_inches='tight')
plt.show()

# %%
ticksize =20
legendsize=19
legbox = 19
titlesize = 26


fig, ax = plt.subplots(figsize=[14, 7])

# Create a bar plot with custom color, opacity, and border
css=ax.bar(rmm_ph, mjo_conn_ts, color='dodgerblue', alpha=0.7, edgecolor='black')

ax.set_title('DJFM MJO-Connected RMM Hours', fontsize=titlesize)
ax.set_xlabel('[RMM Phase]', fontsize=legendsize)
ax.set_ylabel('[Hours]', fontsize=legendsize)
plt.yticks(fontsize=ticksize)
plt.xticks(fontsize=ticksize)

fig.savefig("/home/disk/orca/csmall3/AR_testing_research/JGR_Man_Scripts/Spatial_Distributions/MJO_LPT/Figures/MJO_Conn_RMM_Hours_Dist.png", dpi=350, bbox_inches='tight')
plt.show()
